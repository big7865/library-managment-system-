# %%
class Library:
    def _init(self,list,name,book):
        self.book=list
        self.name=name
        self.lendDict={}
        
         
    def book(self, author, title, book_id):
        self.author = author
        self.title = title
        self.book_id = book_id

    def __str__(self):
        return 'Book(author, title, book_id)'

    def __repr__(self):

        return 'Book(author, title, book_id)'

    def __eq__(self, other):

    #Not sure if this is the right approach

        for title in Book:
            for title in Book:
                if title == title:
                    if author == author:
                        if book_id == book_id:
                            return True 
                        
                        
                        def borrower(self,register,full name,date of birth, contact no. ,email address, password):
                            if borrower not in self.borrower():
                                self.borrower.update([register]):
                                self.register.update(["full name","date of birth","contact no.","email address","password"])
                                print("registration successfully")
                        
                        
        
        
        def DisplayBooks(self):
        print(f"we have following books in our library:{self.name}")
        for book in self.booklist:
            print("book")
            
    def lendBook(self,user,book):
        if book not in self.lendDict.keys():
            self.lendDict.update({book.user})
            print("Lender-Book database has been updated you can take book now")
        else:
            print("Book is already in use by {self.lendDict[book]}")
            
        def addBook(self,book):
            self.booklist.append(book)
            print("Book has been added to the list")
            
        def returnBook(self,book):
            self.lendDict.pop(book)
            
            
        if _name_=='_main_':
            bigyanshu=Library(['python','java','prince of persia','harry potter','two states'],"LMS")
            while(True):
                print(f"welcome to the{bigyanshu.name}library.Enter your choice to continue")
                print("1.Display books")
                print("2.Lend books")
                print("3.Add book")
                print("4.Return book")
                user_choice=input()
                if user_choice in ['1','2','3','4']:
                    continue
                else:
                    user_choice=int(user_choice)
                    
                if user_choice==1:
                    bigyanshu.displayBooks()
                  
                elif user_choice==2:
                    book=input("Enter the name of book you want to lend:")
                    user=input("Enter your name")
                    bigyanshu.lendBook(user,book)
                  
                elif user_choice==3:
                    book=input("Enter the name of book you want to add:")
                    bigyanshu.addBook(book)
                  
                elif user_choice==4:
                    book=input("Enter the name of book you want to return:")
                    bigyanshu.returnBook(book)
                  
               
                
                else:
                    print("not a vaild option")
                  
                print("press a to quit and c to continue")
                user_choice2=""
                if user_choice2=="q":
                    exit()
                    if user_choice2=="c":
                        continue
                        
                    def(self,server,username, password):
                        self.server = 'dbhost1'
                        self.user = 'admin'
                        self.password = 'admin'
                        from settings import server, user, password 
                        db_connect(db_server, db_user, db_password)
